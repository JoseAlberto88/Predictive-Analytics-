# %% [markdown]
# <a href="https://colab.research.google.com/github/JoseAlberto88/Predictive-Analytics-/blob/main/DAMO510%2C_Module_10%2C_in_Class_Activity%2C_Starter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import (
    train_test_split,
    GridSearchCV,
    KFold,
    StratifiedKFold,
    cross_val_score
)
from sklearn.metrics import (
    mean_squared_error,
    r2_score,
    confusion_matrix,
    accuracy_score,
    classification_report,
    roc_curve,
    roc_auc_score
)

from xgboost import XGBRegressor, XGBClassifier, plot_importance

# %%
# ---------------------------------------------------------
# Part 1: Data Preparation
# ---------------------------------------------------------

# Load dataset
data = fetch_california_housing(as_frame=True)
df_a = data.frame.copy()

print("First 5 rows:")
print(df_a.head())

print("\nDataset shape:", df_a.shape)

print("\nSummary statistics:")
print(df_a.describe())

print("\nMissing values:")
print(df_a.isnull().sum())

# Create classification target


# Features and targets


# Train/test split

# %%
# ---------------------------------------------------------
# Part 2: Regression Modeling
# ---------------------------------------------------------



# Standard metrics


# Relative metrics




# Plot regression feature importance

# %%
# ---------------------------------------------------------
# Part 3: Classification Modeling
# ---------------------------------------------------------




# Get predicted probabilities (IMPORTANT for ROC)


# Compute ROC curve


# Compute AUC


# Plot classification feature importance

# %%
# ---------------------------------------------------------
# Part 4: Model Comparison
# ---------------------------------------------------------

# %%
# ---------------------------------------------------------
# Part 6: Bonus Task — Parameter Tuning
# ---------------------------------------------------------


# Regression tuning


# Classification tuning


# ---------------------------------------------------------
# Cross Validation
# ---------------------------------------------------------


# Regression CV


# Classification CV


# ---------------------------------------------------------
# Base Model vs Tuned Model
# ---------------------------------------------------------
