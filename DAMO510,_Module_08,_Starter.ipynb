# %% [markdown]
# <a href="https://colab.research.google.com/github/JoseAlberto88/Predictive-Analytics-/blob/main/DAMO510%2C_Module_08%2C_Starter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Loading Libraries and Dataset and Start Data Pre-Processing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB, MultinomialNB
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, f1_score, roc_curve, roc_auc_score

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
DATA_FILE = '/content/drive/MyDrive/Predictive Analytics Course/Dataset1.csv'
df = pd.read_csv(DATA_FILE)

print("Initial shape:", df.shape)
df.head()
# Out:
# Initial shape: (2000, 17)
#    Cust_No  avg_order_size  avg_order_freq  crossbuy  multichannel  per_sale  \
# 0        1       23.400000        2.222222         3             2  0.000000
# 1        2       34.260377        6.625000         7             2  0.111111
# 2        3       43.575641        4.875000         5             2  0.074074
# 3        4       26.316667        0.900000         4             2  0.250000
# 4        5        8.269231        1.083333         3             1  0.500000
#
#    tenure  return_rate  married  own_home  household_size  loyalty_card  \
# 0       3     0.117521        1         1               1             1
# 1      35     0.281868        1         1               3             1
# 2      12     0.274177        1         0               4             0
# 3       9     0.143551        0         0               1             1
# 4      40     0.000000        0         0               2             0
#
# ...

# %%
# Load your dataset (replace with your actual file path)
df_a = pd.read_csv('DAMO510, Module 08, Dataset1.csv')

# Preview the data
print(df_a.head())
print(df_a.shape)

# %%
# Define target variable
y = df_a['segment']

# Select numerical features for LDA
X = df_a.drop(columns=["Cust_No", "zip_code", "segment"])

# %%
# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
